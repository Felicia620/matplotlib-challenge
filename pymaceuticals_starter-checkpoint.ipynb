# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
combined_data_df = pd.merge(mouse_metadata, study_results, on = "Mouse ID")

# Display the data table for preview
combined_data_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice

mouse_count = pd.DataFrame(
    
    {"Number of Mice": [combined_data_df["Mouse ID"].nunique()]})

mouse_count
# Out:
#    Number of Mice
# 0             249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint

duplicate_mice = combined_data_df[combined_data_df.duplicated(subset = ["Mouse ID", "Timepoint"])]

duplicate_mice
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 911           47.570392                 0
# 913           49.880528                 0
# 915           53.442020                 0
# 917           54.657650                 1

# %%
# Optional: Get all the data for the duplicate mouse ID

all_data_duplicate_mouse_id = combined_data_df[combined_data_df["Mouse ID"] == "g989"]

all_data_duplicate_mouse_id
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID

clean_combined_data = combined_data_df[combined_data_df["Mouse ID"] != "g989"]

clean_combined_data
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame

mouse_count = pd.DataFrame(
    
    {"Number of Mice": [clean_combined_data["Mouse ID"].nunique()]})

mouse_count
# Out:
#    Number of Mice
# 0             248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM 
# of the tumor volume for each regimen

regimen_mean = clean_combined_data.groupby("Drug Regimen").mean()["Tumor Volume (mm3)"]

regimen_median = clean_combined_data.groupby("Drug Regimen").median()["Tumor Volume (mm3)"]

regimen_variance = clean_combined_data.groupby("Drug Regimen").var()["Tumor Volume (mm3)"]

regimen_standard_deviation = clean_combined_data.groupby("Drug Regimen").std()["Tumor Volume (mm3)"]

regimen_standard_error_mean = clean_combined_data.groupby("Drug Regimen").sem()["Tumor Volume (mm3)"]

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume 
# Assemble the resulting series into a single summary dataframe

summary_table_df = pd.DataFrame(
    
    {"Mean": regimen_mean,
     
     "Median": regimen_median,
     
     "Variance": regimen_variance,
     
     "Standard Deviation": regimen_standard_deviation,
     
     "Standard Error of the Mean": regimen_standard_error_mean})

summary_table_df
# Out:
#                    Mean     Median   Variance  Standard Deviation  \
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764            4.994774
# Ceftamin      52.591172  51.776157  39.290177            6.268188
# Infubinol     52.884795  51.820584  43.128684            6.567243
# Ketapril      55.235638  53.698743  68.553577            8.279709
# Naftisol      54.331565  52.509285  66.173479            8.134708
# Placebo       54.033581  52.288934  61.168083            7.821003
# Propriva      52.320930  50.446266  43.852013            6.622085
# Ramicane      40.216745  40.673236  23.486704            4.846308
# Stelasyn      54.233149  52.431737  59.450562            7.710419
# Zoniferol     53.236507  51.818479  48.533355            6.966589
#
#               Standard Error of the Mean
# Drug Regimen
# Capomulin                       0.329346
# Ceftamin                        0.469821
# Infubinol                       0.492236
# Ketapril                        0.603860
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line

aggregate_summary_table = clean_combined_data.groupby("Drug Regimen").agg(["mean",
                                                                           "median",
                                                                           "var",
                                                                           "std",
                                                                           "sem"])["Tumor Volume (mm3)"]

aggregate_summary_table
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas

mice_count_per_regimen = clean_combined_data.groupby(["Drug Regimen"]).count()["Mouse ID"] 

mice_count_per_regimen.plot.bar(color = "blue", fontsize = 15)

plt.xlabel("Drug Regimen", fontsize = 15)

plt.ylabel("Number of Mice", fontsize = 15)

plt.title("Mice Count per Regimen", fontsize = 20)

plt.show()

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot

mice_count_per_regimen_list = (clean_combined_data.groupby(["Drug Regimen"])["Mouse ID"].count()).tolist()

mice_count_per_regimen_list
# Out:
# [230, 178, 178, 188, 186, 181, 148, 228, 181, 182]

# %%
x_axis = np.arange(len(mice_count_per_regimen))

plt.bar(x_axis, mice_count_per_regimen_list, color = "blue")

ticks = [value for value in x_axis]

plt.xticks(ticks, ["Capomulin",
                   "Ceftamin",
                   "Infubinol",
                   "Ketapril",
                   "Naftisol",
                   "Placebo",
                   "Propriva",
                   "Ramicane",
                   "Stelasyn",
                   "Zoniferol"], rotation = "vertical")

plt.xlim(-1, len(x_axis))

plt.ylim(0, max(mice_count_per_regimen_list) + 5)

plt.title("Mice Count Per Regimen", fontsize = 20)

plt.xlabel("Drug Regimen", fontsize = 15)

plt.ylabel("Mice Count", fontsize = 15)

plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas

groupby_sex = clean_combined_data.groupby(["Mouse ID", "Sex"])

mouse_sex_df = pd.DataFrame(groupby_sex.size())

mouse_sex = pd.DataFrame(mouse_sex_df.groupby(["Sex"]).count())

mouse_sex.columns = ["Total Count"]

mouse_sex["Percentage"] = (mouse_sex["Total Count"] / mouse_sex["Total Count"].sum()) * 100

mouse_sex
# Out:
#         Total Count  Percentage
# Sex
# Female          123   49.596774
# Male            125   50.403226

# %%
colors = ["red", "blue"]

plot = mouse_sex.plot.pie(y = "Total Count",
                         colors = colors,
                         autopct = "%1.1f%%")

plt.title("Male versus Female Mice", fontsize = 20)

plt.ylabel("Sex", fontsize = 15)

plt.axis("equal", fontsize = 15)

plt.show()
# Out:
# C:\Users\pajj2\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:11: MatplotlibDeprecationWarning: Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.
#   # This is added back by InteractiveShellApp.init_path()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

labels = ["Female", "Male"]

sizes = [49.596774, 50.403226]

colors = ["red", "blue"]

plt.pie(sizes, labels = labels, colors = colors, autopct = "%1.1f%%")

plt.title("Male versus Female Mice", fontsize = 20)

plt.ylabel("Sex", fontsize = 15)

plt.axis("equal", fontsize = 15)

plt.show()
# Out:
# C:\Users\pajj2\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:15: MatplotlibDeprecationWarning: Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.
#   from ipykernel import kernelapp as app

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse

last_timepoint = clean_combined_data.groupby(["Mouse ID"])["Timepoint"].max()

last_timepoint_df = last_timepoint.reset_index()

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint

tumor_volume_merge = pd.merge(last_timepoint_df, clean_combined_data, on = ("Mouse ID", "Timepoint"))

tumor_volume_merge
# Out:
#     Mouse ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0       a203         45    Infubinol  Female          20          23
# 1       a251         45    Infubinol  Female          21          25
# 2       a262         45      Placebo  Female          17          29
# 3       a275         45     Ceftamin  Female          20          28
# 4       a366         30     Stelasyn  Female          16          29
# ..       ...        ...          ...     ...         ...         ...
# 243     z435         10     Propriva  Female          12          26
# 244     z578         45     Ramicane    Male          11          16
# 245     z581         45    Infubinol  Female          24          25
# 246     z795         45     Naftisol  Female          13          29
# 247     z969         45     Naftisol    Male           9          30
#
#      Tumor Volume (mm3)  Metastatic Sites
# 0             67.973419                 2
# 1             65.525743                 1
# ...

# %%
# Locate the rows which contain mice on each drug and get the tumor volumes
# add subset 

capomulin_df = clean_combined_data.loc[clean_combined_data["Drug Regimen"] == "Capomulin", :]

capomulin_last_timepoint = capomulin_df.groupby("Mouse ID").max()["Timepoint"]

capomulin_tumor_volume = pd.DataFrame(capomulin_last_timepoint)

capomulin_merge = pd.merge(capomulin_tumor_volume, clean_combined_data, on = ("Mouse ID", "Timepoint"))

capomulin_merge
# Out:
#    Mouse ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0      b128         45    Capomulin  Female           9          22
# 1      b742         45    Capomulin    Male           7          21
# 2      f966         20    Capomulin    Male          16          17
# 3      g288         45    Capomulin    Male           3          19
# 4      g316         45    Capomulin  Female          22          22
# 5      i557         45    Capomulin  Female           1          24
# 6      i738         45    Capomulin  Female          23          20
# 7      j119         45    Capomulin  Female           7          23
# 8      j246         35    Capomulin  Female          21          21
# 9      l509         45    Capomulin    Male          17          21
# 10     l897         45    Capomulin    Male          17          19
# 11     m601         45    Capomulin    Male          22          17
# 12     m957         45    Capomulin  Female           3          19
# ...

# %%
# Calculate the IQR and quantitatively determine if there are any potential outliers. 
# Determine outliers using upper and lower bounds

capomulin_tumor_volume = capomulin_merge["Tumor Volume (mm3)"]

capomulin_quartiles = capomulin_tumor_volume.quantile([0.25, 0.5, 0.75])

capomulin_lower_quartile = capomulin_quartiles[0.25]

capomulin_upper_quartile = capomulin_quartiles[0.75]

capomulin_interquartile_range = capomulin_upper_quartile - capomulin_lower_quartile

capomulin_lower_bound = capomulin_lower_quartile - (1.5 * capomulin_interquartile_range)

capomulin_upper_bound = capomulin_upper_quartile + (1.5 * capomulin_interquartile_range)

print(f"The interquartile range of Capomulin tumors is {capomulin_interquartile_range}.")

print(f"Values below {capomulin_lower_bound} are outliers.")

print(f"Values above {capomulin_upper_bound} are outliers.")
# Out:
# The interquartile range of Capomulin tumors is 7.781863460000004.
# Values below 20.70456164999999 are outliers.
# Values above 51.83201549 are outliers.

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

capomulin_tumor_volume = capomulin_merge["Tumor Volume (mm3)"]

fig1, ax1 = plt.subplots()

ax1.set_title("Capomulin Regimen")

ax1.set_ylabel("Final Tumor Volume")

ax1.boxplot(capomulin_tumor_volume)

plt.show()

# %%
# Locate the rows which contain mice on each drug and get the tumor volumes
# add subset 

ramicane_df = clean_combined_data.loc[clean_combined_data["Drug Regimen"] == "Ramicane", :]

ramicane_last_timepoint = ramicane_df.groupby("Mouse ID").max()["Timepoint"]

ramicane_tumor_volume = pd.DataFrame(ramicane_last_timepoint)

ramicane_merge = pd.merge(ramicane_tumor_volume, clean_combined_data, on = ("Mouse ID", "Timepoint"))

ramicane_merge
# Out:
#    Mouse ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0      a411         45     Ramicane    Male           3          22
# 1      a444         45     Ramicane  Female          10          25
# 2      a520         45     Ramicane    Male          13          21
# 3      a644         45     Ramicane  Female           7          17
# 4      c458         30     Ramicane  Female          23          20
# 5      c758         45     Ramicane    Male           9          17
# 6      d251         45     Ramicane  Female           8          19
# 7      e662         45     Ramicane    Male           8          24
# 8      g791         45     Ramicane    Male          11          16
# 9      i177         45     Ramicane    Male          10          18
# 10     i334         45     Ramicane  Female           8          20
# 11     j913         45     Ramicane  Female           4          17
# 12     j989         45     Ramicane    Male           8          19
# ...

# %%
# Calculate the IQR and quantitatively determine if there are any potential outliers. 
# Determine outliers using upper and lower bounds

ramicane_tumor_volume = ramicane_merge["Tumor Volume (mm3)"]

ramicane_quartiles = ramicane_tumor_volume.quantile([0.25, 0.5, 0.75])

ramicane_lower_quartile = ramicane_quartiles[0.25]

ramicane_upper_quartile = ramicane_quartiles[0.75]

ramicane_interquartile_range = ramicane_upper_quartile - ramicane_lower_quartile

ramicane_lower_bound = ramicane_lower_quartile - (1.5 * ramicane_interquartile_range)

ramicane_upper_bound = ramicane_upper_quartile + (1.5 * ramicane_interquartile_range)

print(f"The interquartile range of Ramicane tumors is {ramicane_interquartile_range}.")

print(f"Values below {ramicane_lower_bound} could be outliers.")

print(f"Values above {ramicane_upper_bound} could be outliers.")
# Out:
# The interquartile range of Ramicane tumors is 9.098536719999998.
# Values below 17.912664470000003 could be outliers.
# Values above 54.30681135 could be outliers.

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

ramicane_tumor_volume = ramicane_merge["Tumor Volume (mm3)"]

fig1, ax1 = plt.subplots()

ax1.set_title("Ramicane Regimen")

ax1.set_ylabel("Final Tumor Volume")

ax1.boxplot(ramicane_tumor_volume)

plt.show()

# %%
# Locate the rows which contain mice on each drug and get the tumor volumes
# add subset 

infubinol_df = clean_combined_data.loc[clean_combined_data["Drug Regimen"] == "Infubinol", :]

infubinol_last_timepoint = infubinol_df.groupby("Mouse ID").max()["Timepoint"]

infubinol_tumor_volume = pd.DataFrame(infubinol_last_timepoint)

infubinol_merge = pd.merge(infubinol_tumor_volume, clean_combined_data, on = ("Mouse ID", "Timepoint"))

infubinol_merge
# Out:
#    Mouse ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0      a203         45    Infubinol  Female          20          23
# 1      a251         45    Infubinol  Female          21          25
# 2      a577         30    Infubinol  Female           6          25
# 3      a685         45    Infubinol    Male           8          30
# 4      c139         45    Infubinol    Male          11          28
# 5      c326          5    Infubinol  Female          18          25
# 6      c895         30    Infubinol  Female           7          29
# 7      e476         45    Infubinol    Male          23          26
# 8      f345         45    Infubinol    Male          23          26
# 9      i386         40    Infubinol  Female          23          29
# 10     k483         45    Infubinol  Female          20          30
# 11     k804         35    Infubinol  Female          23          29
# 12     m756          5    Infubinol    Male          19          30
# ...

# %%
# Calculate the IQR and quantitatively determine if there are any potential outliers. 
# Determine outliers using upper and lower bounds

infubinol_tumor_volume = infubinol_merge["Tumor Volume (mm3)"]

infubinol_quartiles = infubinol_tumor_volume.quantile([0.25, 0.5, 0.75])

infubinol_lower_quartile = infubinol_quartiles[0.25]

infubinol_upper_quartile = infubinol_quartiles[0.75]

infubinol_interquartile_range = infubinol_upper_quartile - infubinol_lower_quartile

infubinol_lower_bound = infubinol_lower_quartile - (1.5 * infubinol_interquartile_range)

infubinol_upper_bound = infubinol_upper_quartile + (1.5 * infubinol_interquartile_range)

print(f"The interquartile range of Infubinol tumors is {infubinol_interquartile_range}.")

print(f"Values below {infubinol_lower_bound} are outliers.")

print(f"Values above {infubinol_upper_bound} are outliers.")
# Out:
# The interquartile range of Infubinol tumors is 11.477135160000003.
# Values below 36.83290494999999 are outliers.
# Values above 82.74144559000001 are outliers.

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

infubinol_tumor_volume = infubinol_merge["Tumor Volume (mm3)"]

fig1, ax1 = plt.subplots()

ax1.set_title("Infubinol Drug")

ax1.set_ylabel("Final Tumor Volume")

ax1.boxplot(infubinol_tumor_volume)

plt.show()

# %%
# Locate the rows which contain mice on each drug and get the tumor volumes
# add subset 

ceftamin_df = clean_combined_data.loc[clean_combined_data["Drug Regimen"] == "Ceftamin", :]

ceftamin_last_timepoint = ceftamin_df.groupby("Mouse ID").max()["Timepoint"]

ceftamin_tumor_volume = pd.DataFrame(ceftamin_last_timepoint)

ceftamin_merge = pd.merge(ceftamin_tumor_volume, clean_combined_data, on = ("Mouse ID", "Timepoint"))

ceftamin_merge
# Out:
#    Mouse ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0      a275         45     Ceftamin  Female          20          28
# 1      b447          0     Ceftamin    Male           2          30
# 2      b487         25     Ceftamin  Female           6          28
# 3      b759         30     Ceftamin  Female          12          25
# 4      f436         15     Ceftamin  Female           3          25
# 5      h531          5     Ceftamin    Male           5          27
# 6      j296         45     Ceftamin  Female          24          30
# 7      k210         45     Ceftamin    Male          15          28
# 8      l471         45     Ceftamin  Female           7          28
# 9      l490         30     Ceftamin    Male          24          26
# 10     l558         10     Ceftamin  Female          13          30
# 11     l661         45     Ceftamin    Male          18          26
# 12     l733         45     Ceftamin  Female           4          30
# ...

# %%
# Calculate the IQR and quantitatively determine if there are any potential outliers. 
# Determine outliers using upper and lower bounds

ceftamin_tumor_volume = ceftamin_merge["Tumor Volume (mm3)"]

ceftamin_quartiles = ceftamin_tumor_volume.quantile([0.25, 0.5, 0.75])

ceftamin_lower_quartile = ceftamin_quartiles[0.25]

ceftamin_upper_quartile = ceftamin_quartiles[0.75]

ceftamin_interquartile_range = ceftamin_upper_quartile - ceftamin_lower_quartile

ceftamin_lower_bound = ceftamin_lower_quartile - (1.5 * ceftamin_interquartile_range)

ceftamin_upper_bound = ceftamin_upper_quartile + (1.5 * ceftamin_interquartile_range)

print(f"The interquartile range of temperatures is {ceftamin_interquartile_range}.")

print(f"Values below {ceftamin_lower_bound} are outliers.")

print(f"Values above {ceftamin_upper_bound} are outliers.")
# Out:
# The interquartile range of temperatures is 15.577752179999997.
# Values below 25.355449580000002 are outliers.
# Values above 87.66645829999999 are outliers.

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

ceftamin_tumor_volume = ceftamin_merge["Tumor Volume (mm3)"]

fig1, ax1 = plt.subplots()

ax1.set_title("Ceftamin Regimen")

ax1.set_ylabel("Final Tumor Volume")

ax1.boxplot(ceftamin_tumor_volume)

plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin

capomulin_mouse_df = capomulin_df.loc[capomulin_df["Mouse ID"] == "b128", :]

capomulin_mouse_df
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 300     b128    Capomulin  Female           9          22          0
# 301     b128    Capomulin  Female           9          22          5
# 302     b128    Capomulin  Female           9          22         10
# 303     b128    Capomulin  Female           9          22         15
# 304     b128    Capomulin  Female           9          22         20
# 305     b128    Capomulin  Female           9          22         25
# 306     b128    Capomulin  Female           9          22         30
# 307     b128    Capomulin  Female           9          22         35
# 308     b128    Capomulin  Female           9          22         40
# 309     b128    Capomulin  Female           9          22         45
#
#      Tumor Volume (mm3)  Metastatic Sites
# 300           45.000000                 0
# 301           45.651331                 0
# 302           43.270852                 0
# ...

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin

x_axis = capomulin_mouse_df["Timepoint"]

tumor_volume = capomulin_mouse_df["Tumor Volume (mm3)"]

plt.title("Capomulin Regimen - Mouse b128", fontsize = 20)

plt.plot(x_axis, tumor_volume, linewidth = 2, markersize = 10, marker = "o", color = "blue")

plt.xlabel("Timepoint", fontsize = 15)

plt.ylabel("Tumor Volume (mm3)", fontsize = 15)

plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

capomulin_average = capomulin_df.groupby("Mouse ID").mean()

x = capomulin_average["Weight (g)"]

y = capomulin_average["Tumor Volume (mm3)"]

plt.scatter(x, y)

plt.xlabel("Mouse Weight")

plt.ylabel("Average Tumor Volume")

plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen

correlation_coefficient = round(st.pearsonr(capomulin_average["Weight (g)"], capomulin_average["Tumor Volume (mm3)"])[0], 2)

print(f"The correlation between mouse weight and average tumor volume for the Capomulin regimen is {correlation_coefficient}.")
# Out:
# The correlation between mouse weight and average tumor volume for the Capomulin regimen is 0.84.

# %%
# Printed equation manually in cell below, plt.annotate did not work

x_values = capomulin_average["Weight (g)"]

y_values = capomulin_average["Tumor Volume (mm3)"]

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

plt.scatter(x_values,y_values)

plt.plot(x_values, regress_values,"r")

plt.figtext(.55, .35, "y = 0.95x + 21.55", fontsize = 15, color = "red")

plt.xlabel("Weight (g)")

plt.ylabel("Tumor Volume (mm3)")

plt.show()

# %%
print(line_eq)
# Out:
# y = 0.95x + 21.55
